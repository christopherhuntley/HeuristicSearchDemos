# %% [markdown]
# # The Traveling Salesman Problem (TSP)
# _A Heuristic Search Primer_
#
# ## A Classic Problem
# The TSP is one of the oldest and most studied of all heuristic search problems, the subject of _many thousands_ of published academic papers going back to at least the 1930s. It is very easy to state: given i) a list of cities and ii) the road distances between them, find the shortest (minimum distance) "tour" that visits each city exactly once. However, it is very difficult to solve to optimality, even for relatively modest instances.
#
# Here we will consider the ultimate summer road trip: starting (and ending) in Boston, visit each major league or AAA baseball park in the US. The trip is likely to be at least 10,000 miles (about two round trips between Boston and Los Angeles) but can be much, much longer if we are not careful.
#
# Let's see what that looks like. (Note: The snippet of code below is in Python, but we can do this in just about any language. For explanatory clarity and performance reasons, most of the code is hidden away in the `tsp.py` file in this folder. Take a peek if you dare!)

# %%
# import the baseball data and display the cities as a Pandas DataFrame. 
from tsp import *
cities_df[['City','Teams']]
# Out:
# [('San Francisco, CA', 'San Francisco, CA', 0)]
#                     City                                        Teams
# 0            Buffalo, NY                         Buffalo Bisons (AAA)
# 1          Charlotte, NC                      Charlotte Knights (AAA)
# 2           Columbus, OH                      Columbus Clippers (AAA)
# 3             Durham, NC                           Durham Bulls (AAA)
# 4       Indianapolis, IN                   Indianapolis Indians (AAA)
# 5          Allentown, PA                 Lehigh Valley IronPigs (AAA)
# 6         Louisville, KY                        Louisville Bats (AAA)
# 7            Norfolk, VA                          Norfolk Tides (AAA)
# 8          Pawtucket, RI                      Pawtucket Red Sox (AAA)
# 9          Rochester, NY                    Rochester Red Wings (AAA)
# 10          Scranton, PA       Scranton/Wilkes-Barre RailRiders (AAA)
# 11          Syracuse, NY                          Syracuse Mets (AAA)
# 12            Toledo, OH                        Toledo Mud Hens (AAA)
# 13       Albuquerque, NM                   Albuquerque Isotopes (AAA)
# 14           El Paso, TX                     El Paso Chihuahuas (AAA)
# 15            Fresno, CA                       Fresno Grizzlies (AAA)
# 16        Des Moines, IA                              Iowa Cubs (AAA)
# 17         Las Vegas, NV                     Las Vegas Aviators (AAA)
# 18           Memphis, TN                       Memphis Redbirds (AAA)
# 19         Nashville, TN                       Nashville Sounds (AAA)
# 20     Oklahoma City, OK                  Oklahoma City Dodgers (AAA)
# 21             Omaha, NE                    Omaha Storm Chasers (AAA)
# 22              Reno, NV                              Reno Aces (AAA)
# 23        Round Rock, TX                     Round Rock Express (AAA)
# 24   West Sacramento, CA                  Sacramento River Cats (AAA)
# 25       San Antonio, TX                   San Antonio Missions (AAA)
# 26    Salt Lake City, UT                         Salt Lake Bees (AAA)
# 27            Tacoma, WA                        Tacoma Rainiers (AAA)
# 28           Wichita, KS                            Wichita PCL (AAA)
# 29         Baltimore, MD                       Baltimore Orioles (AL)
# 30            Boston, MA                          Boston Red Sox (AL)
# 31     New York City, NY    New York Yankees (AL), New York Mets (NL)
# 32    St. Petersburg, FL                          Tampa Bay Rays (AL)
# 33           Chicago, IL    Chicago White Sox (AL), Chicago Cubs (NL)
# 34         Cleveland, OH                       Cleveland Indians (AL)
# 35           Detroit, MI                          Detroit Tigers (AL)
# 36       Kansas City, MO                      Kansas City Royals (AL)
# 37       Minneapolis, MN                         Minnesota Twins (AL)
# 38           Houston, TX                          Houston Astros (AL)
# 39           Anaheim, CA                      Los Angeles Angels (AL)
# 40           Oakland, CA                       Oakland Athletics (AL)
# 41           Seattle, WA                        Seattle Mariners (AL)
# 42         Arlington, TX                           Texas Rangers (AL)
# 43           Atlanta, GA  Atlanta Braves (NL),Gwinnett Stripers (AAA)
# 44             Miami, FL                           Miami Marlins (NL)
# 45      Philadelphia, PA                   Philadelphia Phillies (NL)
# 46  Washington, D.C., DC                    Washington Nationals (NL)
# 47        Cincinnati, OH                         Cincinnati Reds (NL)
# 48         Milwaukee, WI                       Milwaukee Brewers (NL)
# 49        Pittsburgh, PA                      Pittsburgh Pirates (NL)
# 50         St. Louis, MO                     St. Louis Cardinals (NL)
# 51           Phoenix, AZ                    Arizona Diamondbacks (NL)
# 52            Denver, CO                        Colorado Rockies (NL)
# 53       Los Angeles, CA                     Los Angeles Dodgers (NL)
# 54         San Diego, CA                        San Diego Padres (NL)
# 55     San Francisco, CA                    San Francisco Giants (NL)

# %%
d_flat = [{'from':city_from[1][0], 'to':city_to[1][0], 'dist':d[city_from[0]][city_to[0]]} for city_from in cities_df.iterrows() for city_to in cities_df.iterrows()]
d_flat
# Out:
# [('Buffalo, NY', 'Buffalo, NY', 0),
#  ('Buffalo, NY', 'Charlotte, NC', 797.47),
#  ('Buffalo, NY', 'Columbus, OH', 390.04),
#  ('Buffalo, NY', 'Durham, NC', 767.58),
#  ('Buffalo, NY', 'Indianapolis, IN', 546.71),
#  ('Buffalo, NY', 'Allentown, PA', 400.66),
#  ('Buffalo, NY', 'Louisville, KY', 651.27),
#  ('Buffalo, NY', 'Norfolk, VA', 691.82),
#  ('Buffalo, NY', 'Pawtucket, RI', 636.06),
#  ('Buffalo, NY', 'Rochester, NY', 72.19),
#  ('Buffalo, NY', 'Scranton, PA', 331.48),
#  ('Buffalo, NY', 'Syracuse, NY', 149.14),
#  ('Buffalo, NY', 'Toledo, OH', 335.42),
#  ('Buffalo, NY', 'Albuquerque, NM', 2190.62),
#  ('Buffalo, NY', 'El Paso, TX', 2188.55),
#  ('Buffalo, NY', 'Fresno, CA', 3227.07),
#  ('Buffalo, NY', 'Des Moines, IA', 1083.6),
#  ('Buffalo, NY', 'Las Vegas, NV', 2925.33),
#  ('Buffalo, NY', 'Memphis, TN', 1025.55),
#  ('Buffalo, NY', 'Nashville, TN', 842.26),
#  ('Buffalo, NY', 'Oklahoma City, OK', 1507.62),
#  ('Buffalo, NY', 'Omaha, NE', 1193.82),
#  ('Buffalo, NY', 'Reno, NV', 2903.79),
#  ('Buffalo, NY', 'Round Rock, TX', 1671.07),
#  ('Buffalo, NY', 'West Sacramento, CA', 3038.49),
#  ('Buffalo, NY', 'San Antonio, TX', 1783.84),
#  ('Buffalo, NY', 'Salt Lake City, UT', 2505.34),
#  ('Buffalo, NY', 'Tacoma, WA', 3073.7),
#  ('Buffalo, NY', 'Wichita, KS', 1253.98),
#  ('Buffalo, NY', 'Baltimore, MD', 443.51),
#  ('Buffalo, NY', 'Boston, MA', 676.92),
#  ('Buffalo, NY', 'New York City, NY', 463.44),
#  ('Buffalo, NY', 'St. Petersburg, FL', 1390.98),
#  ('Buffalo, NY', 'Chicago, IL', 582.96),
#  ('Buffalo, NY', 'Cleveland, OH', 214.66),
#  ('Buffalo, NY', 'Detroit, MI', 252.42),
#  ('Buffalo, NY', 'Kansas City, MO', 1058.19),
#  ('Buffalo, NY', 'Minneapolis, MN', 1033.57),
#  ('Buffalo, NY', 'Houston, TX', 1749.14),
#  ('Buffalo, NY', 'Anaheim, CA', 2987.85),
#  ('Buffalo, NY', 'Oakland, CA', 3116.7),
#  ('Buffalo, NY', 'Seattle, WA', 3060.8),
#  ('Buffalo, NY', 'Arlington, TX', 1509.29),
#  ('Buffalo, NY', 'Atlanta, GA', 1037.95),
#  ('Buffalo, NY', 'Miami, FL', 1515.89),
#  ('Buffalo, NY', 'Philadelphia, PA', 445.22),
#  ('Buffalo, NY', 'Washington, D.C., DC', 489.07),
#  ('Buffalo, NY', 'Cincinnati, OH', 495.18),
#  ('Buffalo, NY', 'Milwaukee, WI', 672.33),
#  ('Buffalo, NY', 'Pittsburgh, PA', 292.77),
#  ('Buffalo, NY', 'St. Louis, MO', 845.38),
#  ('Buffalo, NY', 'Phoenix, AZ', 2625.18),
#  ('Buffalo, NY', 'Denver, CO', 1651.75),
#  ('Buffalo, NY', 'Los Angeles, CA', 2998.76),
#  ('Buffalo, NY', 'San Diego, CA', 2920.03),
#  ('Buffalo, NY', 'San Francisco, CA', 3122.32),
#  ('Charlotte, NC', 'Buffalo, NY', 794.26),
#  ('Charlotte, NC', 'Charlotte, NC', 0),
#  ('Charlotte, NC', 'Columbus, OH', 448.92),
#  ('Charlotte, NC', 'Durham, NC', 140.38),
#  ('Charlotte, NC', 'Indianapolis, IN', 621.39),
#  ('Charlotte, NC', 'Allentown, PA', 561.34),
#  ('Charlotte, NC', 'Louisville, KY', 510.36),
#  ('Charlotte, NC', 'Norfolk, VA', 326.69),
#  ('Charlotte, NC', 'Pawtucket, RI', 850.33),
#  ('Charlotte, NC', 'Rochester, NY', 889.4),
#  ('Charlotte, NC', 'Scranton, PA', 590.54),
#  ('Charlotte, NC', 'Syracuse, NY', 964.12),
#  ('Charlotte, NC', 'Toledo, OH', 591.23),
#  ('Charlotte, NC', 'Albuquerque, NM', 1804.74),
#  ('Charlotte, NC', 'El Paso, TX', 1802.67),
#  ('Charlotte, NC', 'Fresno, CA', 2841.19),
#  ('Charlotte, NC', 'Des Moines, IA', 1175.78),
#  ('Charlotte, NC', 'Las Vegas, NV', 2539.45),
#  ('Charlotte, NC', 'Memphis, TN', 726.22),
#  ('Charlotte, NC', 'Nashville, TN', 515.11),
#  ('Charlotte, NC', 'Oklahoma City, OK', 1287.6),
#  ('Charlotte, NC', 'Omaha, NE', 1286.0),
#  ('Charlotte, NC', 'Reno, NV', 3123.92),
#  ('Charlotte, NC', 'Round Rock, TX', 1285.19),
#  ('Charlotte, NC', 'West Sacramento, CA', 3003.68),
#  ('Charlotte, NC', 'San Antonio, TX', 1397.96),
#  ('Charlotte, NC', 'Salt Lake City, UT', 2600.06),
#  ('Charlotte, NC', 'Tacoma, WA', 3293.83),
#  ('Charlotte, NC', 'Wichita, KS', 1253.48),
#  ('Charlotte, NC', 'Baltimore, MD', 444.57),
#  ('Charlotte, NC', 'Boston, MA', 891.19),
#  ('Charlotte, NC', 'New York City, NY', 629.14),
#  ('Charlotte, NC', 'St. Petersburg, FL', 596.48),
#  ('Charlotte, NC', 'Chicago, IL', 803.09),
#  ('Charlotte, NC', 'Cleveland, OH', 545.22),
#  ('Charlotte, NC', 'Detroit, MI', 655.11),
#  ('Charlotte, NC', 'Kansas City, MO', 1150.37),
#  ('Charlotte, NC', 'Minneapolis, MN', 1253.7),
#  ('Charlotte, NC', 'Houston, TX', 1216.46),
#  ('Charlotte, NC', 'Anaheim, CA', 2601.97),
#  ('Charlotte, NC', 'Oakland, CA', 2989.21),
#  ('Charlotte, NC', 'Seattle, WA', 3280.93),
#  ('Charlotte, NC', 'Arlington, TX', 1123.41),
#  ('Charlotte, NC', 'Atlanta, GA', 245.08),
#  ('Charlotte, NC', 'Miami, FL', 721.38),
#  ('Charlotte, NC', 'Philadelphia, PA', 540.84),
#  ('Charlotte, NC', 'Washington, D.C., DC', 399.04),
#  ('Charlotte, NC', 'Cincinnati, OH', 494.02),
#  ('Charlotte, NC', 'Milwaukee, WI', 892.46),
#  ('Charlotte, NC', 'Pittsburgh, PA', 509.07),
#  ('Charlotte, NC', 'St. Louis, MO', 885.06),
#  ('Charlotte, NC', 'Phoenix, AZ', 2239.3),
#  ('Charlotte, NC', 'Denver, CO', 2078.01),
#  ('Charlotte, NC', 'Los Angeles, CA', 2612.88),
#  ('Charlotte, NC', 'San Diego, CA', 2534.16),
#  ('Charlotte, NC', 'San Francisco, CA', 3000.04),
#  ('Columbus, OH', 'Buffalo, NY', 382.82),
#  ('Columbus, OH', 'Charlotte, NC', 448.27),
#  ('Columbus, OH', 'Columbus, OH', 0),
#  ('Columbus, OH', 'Durham, NC', 517.05),
#  ('Columbus, OH', 'Indianapolis, IN', 205.46),
#  ('Columbus, OH', 'Allentown, PA', 477.71),
#  ('Columbus, OH', 'Louisville, KY', 259.84),
#  ('Columbus, OH', 'Norfolk, VA', 590.0),
#  ('Columbus, OH', 'Pawtucket, RI', 892.74),
#  ('Columbus, OH', 'Rochester, NY', 477.95),
#  ('Columbus, OH', 'Scranton, PA', 588.16),
#  ('Columbus, OH', 'Syracuse, NY', 552.67),
#  ('Columbus, OH', 'Toledo, OH', 149.92),
#  ('Columbus, OH', 'Albuquerque, NM', 1847.49),
#  ('Columbus, OH', 'El Paso, TX', 1845.42),
#  ('Columbus, OH', 'Fresno, CA', 2883.94),
#  ('Columbus, OH', 'Des Moines, IA', 777.06),
#  ('Columbus, OH', 'Las Vegas, NV', 2582.2),
#  ('Columbus, OH', 'Memphis, TN', 682.42),
#  ('Columbus, OH', 'Nashville, TN', 497.83),
#  ('Columbus, OH', 'Oklahoma City, OK', 1164.49),
#  ('Columbus, OH', 'Omaha, NE', 887.28),
#  ('Columbus, OH', 'Reno, NV', 2677.35),
#  ('Columbus, OH', 'Round Rock, TX', 1327.94),
#  ('Columbus, OH', 'West Sacramento, CA', 2812.05),
#  ('Columbus, OH', 'San Antonio, TX', 1440.71),
#  ('Columbus, OH', 'Salt Lake City, UT', 2278.9),
#  ('Columbus, OH', 'Tacoma, WA', 2847.26),
#  ('Columbus, OH', 'Wichita, KS', 947.44),
#  ('Columbus, OH', 'Baltimore, MD', 413.23),
#  ('Columbus, OH', 'Boston, MA', 933.59),
#  ('Columbus, OH', 'New York City, NY', 720.11),
#  ('Columbus, OH', 'St. Petersburg, FL', 1041.79),
#  ('Columbus, OH', 'Chicago, IL', 356.52),
#  ('Columbus, OH', 'Cleveland, OH', 150.68),
#  ('Columbus, OH', 'Detroit, MI', 198.1),
#  ('Columbus, OH', 'Kansas City, MO', 751.65),
#  ('Columbus, OH', 'Minneapolis, MN', 807.13),
#  ('Columbus, OH', 'Houston, TX', 1406.01),
#  ('Columbus, OH', 'Anaheim, CA', 2644.72),
#  ('Columbus, OH', 'Oakland, CA', 3031.96),
#  ('Columbus, OH', 'Seattle, WA', 2834.36),
#  ('Columbus, OH', 'Arlington, TX', 1166.16),
#  ('Columbus, OH', 'Atlanta, GA', 655.74),
#  ('Columbus, OH', 'Miami, FL', 1166.69),
#  ('Columbus, OH', 'Philadelphia, PA', 487.05),
#  ('Columbus, OH', 'Washington, D.C., DC', 413.93),
#  ('Columbus, OH', 'Cincinnati, OH', 105.77),
#  ('Columbus, OH', 'Milwaukee, WI', 445.89),
#  ('Columbus, OH', 'Pittsburgh, PA', 224.43),
#  ('Columbus, OH', 'St. Louis, MO', 538.84),
#  ('Columbus, OH', 'Phoenix, AZ', 2282.05),
#  ('Columbus, OH', 'Denver, CO', 1345.21),
#  ('Columbus, OH', 'Los Angeles, CA', 2655.63),
#  ('Columbus, OH', 'San Diego, CA', 2576.9),
#  ('Columbus, OH', 'San Francisco, CA', 3042.78),
#  ('Durham, NC', 'Buffalo, NY', 764.0),
#  ('Durham, NC', 'Charlotte, NC', 140.38),
#  ('Durham, NC', 'Columbus, OH', 517.22),
#  ('Durham, NC', 'Durham, NC', 0),
#  ('Durham, NC', 'Indianapolis, IN', 646.77),
#  ('Durham, NC', 'Allentown, PA', 441.78),
#  ('Durham, NC', 'Louisville, KY', 535.74),
#  ('Durham, NC', 'Norfolk, VA', 184.47),
#  ('Durham, NC', 'Pawtucket, RI', 704.56),
#  ('Durham, NC', 'Rochester, NY', 716.89),
#  ('Durham, NC', 'Scranton, PA', 510.6),
#  ('Durham, NC', 'Syracuse, NY', 642.78),
#  ('Durham, NC', 'Toledo, OH', 659.53),
#  ('Durham, NC', 'Albuquerque, NM', 2028.71),
#  ('Durham, NC', 'El Paso, TX', 2026.64),
#  ('Durham, NC', 'Fresno, CA', 3065.16),
#  ('Durham, NC', 'Des Moines, IA', 1201.16),
#  ('Durham, NC', 'Las Vegas, NV', 2763.42),
#  ('Durham, NC', 'Memphis, TN', 863.64),
#  ('Durham, NC', 'Nashville, TN', 617.2),
#  ('Durham, NC', 'Oklahoma City, OK', 1345.71),
#  ('Durham, NC', 'Omaha, NE', 1311.38),
#  ('Durham, NC', 'Reno, NV', 3149.3),
#  ('Durham, NC', 'Round Rock, TX', 1509.16),
#  ('Durham, NC', 'West Sacramento, CA', 3227.65),
#  ('Durham, NC', 'San Antonio, TX', 1621.93),
#  ('Durham, NC', 'Salt Lake City, UT', 2750.85),
#  ('Durham, NC', 'Tacoma, WA', 3319.21),
#  ('Durham, NC', 'Wichita, KS', 1278.85),
#  ('Durham, NC', 'Baltimore, MD', 298.8),
#  ('Durham, NC', 'Boston, MA', 745.42),
#  ('Durham, NC', 'New York City, NY', 483.37),
#  ('Durham, NC', 'St. Petersburg, FL', 682.86),
#  ('Durham, NC', 'Chicago, IL', 828.46),
#  ('Durham, NC', 'Cleveland, OH', 627.37),
#  ('Durham, NC', 'Detroit, MI', 723.41),
#  ('Durham, NC', 'Kansas City, MO', 1175.75),
#  ('Durham, NC', 'Minneapolis, MN', 1279.07),
#  ('Durham, NC', 'Houston, TX', 1587.23),
#  ('Durham, NC', 'Anaheim, CA', 2825.94),
#  ('Durham, NC', 'Oakland, CA', 3213.18),
#  ('Durham, NC', 'Seattle, WA', 3306.3),
#  ('Durham, NC', 'Arlington, TX', 1347.38),
#  ('Durham, NC', 'Atlanta, GA', 381.84),
#  ('Durham, NC', 'Miami, FL', 807.76),
#  ('Durham, NC', 'Philadelphia, PA', 395.07),
#  ('Durham, NC', 'Washington, D.C., DC', 253.27),
#  ('Durham, NC', 'Cincinnati, OH', 519.4),
#  ('Durham, NC', 'Milwaukee, WI', 917.83),
#  ('Durham, NC', 'Pittsburgh, PA', 478.82),
#  ('Durham, NC', 'St. Louis, MO', 910.44),
#  ('Durham, NC', 'Phoenix, AZ', 2463.27),
#  ('Durham, NC', 'Denver, CO', 2301.98),
#  ('Durham, NC', 'Los Angeles, CA', 2836.85),
#  ('Durham, NC', 'San Diego, CA', 2758.12),
#  ('Durham, NC', 'San Francisco, CA', 3224.0),
#  ('Indianapolis, IN', 'Buffalo, NY', 546.68),
#  ('Indianapolis, IN', 'Charlotte, NC', 615.48),
#  ('Indianapolis, IN', 'Columbus, OH', 241.82),
#  ('Indianapolis, IN', 'Durham, NC', 639.93),
#  ('Indianapolis, IN', 'Indianapolis, IN', 0),
#  ('Indianapolis, IN', 'Allentown, PA', 821.2),
#  ('Indianapolis, IN', 'Louisville, KY', 114.67),
#  ('Indianapolis, IN', 'Norfolk, VA', 773.34),
#  ('Indianapolis, IN', 'Pawtucket, RI', 1056.6),
#  ('Indianapolis, IN', 'Rochester, NY', 641.82),
#  ('Indianapolis, IN', 'Scranton, PA', 752.02),
#  ('Indianapolis, IN', 'Syracuse, NY', 716.54),
#  ('Indianapolis, IN', 'Toledo, OH', 225.56),
#  ('Indianapolis, IN', 'Albuquerque, NM', 1654.02),
#  ('Indianapolis, IN', 'El Paso, TX', 1651.95),
#  ('Indianapolis, IN', 'Fresno, CA', 2690.47),
#  ('Indianapolis, IN', 'Des Moines, IA', 554.62),
#  ('Indianapolis, IN', 'Las Vegas, NV', 2388.73),
#  ('Indianapolis, IN', 'Memphis, TN', 488.95),
#  ('Indianapolis, IN', 'Nashville, TN', 305.66),
#  ('Indianapolis, IN', 'Oklahoma City, OK', 971.02),
#  ('Indianapolis, IN', 'Omaha, NE', 664.84),
#  ('Indianapolis, IN', 'Reno, NV', 2502.43),
#  ('Indianapolis, IN', 'Round Rock, TX', 1134.47),
#  ('Indianapolis, IN', 'West Sacramento, CA', 2637.13),
#  ('Indianapolis, IN', 'San Antonio, TX', 1247.24),
#  ('Indianapolis, IN', 'Salt Lake City, UT', 2103.99),
#  ('Indianapolis, IN', 'Tacoma, WA', 2672.34),
#  ('Indianapolis, IN', 'Wichita, KS', 725.0),
#  ('Indianapolis, IN', 'Baltimore, MD', 642.74),
#  ('Indianapolis, IN', 'Boston, MA', 1097.46),
#  ('Indianapolis, IN', 'New York City, NY', 883.98),
#  ('Indianapolis, IN', 'St. Petersburg, FL', 1054.35),
#  ('Indianapolis, IN', 'Chicago, IL', 181.6),
#  ('Indianapolis, IN', 'Cleveland, OH', 332.93),
#  ('Indianapolis, IN', 'Detroit, MI', 286.26),
#  ('Indianapolis, IN', 'Kansas City, MO', 529.21),
#  ('Indianapolis, IN', 'Minneapolis, MN', 632.21),
#  ('Indianapolis, IN', 'Houston, TX', 1212.54),
#  ('Indianapolis, IN', 'Anaheim, CA', 2451.24),
#  ('Indianapolis, IN', 'Oakland, CA', 2838.48),
#  ('Indianapolis, IN', 'Seattle, WA', 2659.44),
#  ('Indianapolis, IN', 'Arlington, TX', 972.69),
#  ('Indianapolis, IN', 'Atlanta, GA', 578.12),
#  ('Indianapolis, IN', 'Miami, FL', 1247.67),
#  ('Indianapolis, IN', 'Philadelphia, PA', 865.76),
#  ('Indianapolis, IN', 'Washington, D.C., DC', 643.45),
#  ('Indianapolis, IN', 'Cincinnati, OH', 106.86),
#  ('Indianapolis, IN', 'Milwaukee, WI', 270.97),
#  ('Indianapolis, IN', 'Pittsburgh, PA', 441.11),
#  ('Indianapolis, IN', 'St. Louis, MO', 255.22),
#  ('Indianapolis, IN', 'Phoenix, AZ', 2088.57),
#  ('Indianapolis, IN', 'Denver, CO', 1122.77),
#  ('Indianapolis, IN', 'Los Angeles, CA', 2462.16),
#  ('Indianapolis, IN', 'San Diego, CA', 2383.43),
#  ('Indianapolis, IN', 'San Francisco, CA', 2849.31),
#  ('Allentown, PA', 'Buffalo, NY', 406.25),
#  ('Allentown, PA', 'Charlotte, NC', 562.4),
#  ('Allentown, PA', 'Columbus, OH', 483.01),
#  ('Allentown, PA', 'Durham, NC', 442.42),
#  ('Allentown, PA', 'Indianapolis, IN', 826.48),
#  ('Allentown, PA', 'Allentown, PA', 0),
#  ('Allentown, PA', 'Louisville, KY', 931.04),
#  ('Allentown, PA', 'Norfolk, VA', 320.04),
#  ('Allentown, PA', 'Pawtucket, RI', 321.81),
#  ('Allentown, PA', 'Rochester, NY', 317.94),
#  ('Allentown, PA', 'Scranton, PA', 74.47),
#  ('Allentown, PA', 'Syracuse, NY', 206.65),
#  ('Allentown, PA', 'Toledo, OH', 615.19),
#  ('Allentown, PA', 'Albuquerque, NM', 2216.86),
#  ('Allentown, PA', 'El Paso, TX', 2214.78),
#  ('Allentown, PA', 'Fresno, CA', 3253.31),
#  ('Allentown, PA', 'Des Moines, IA', 1363.37),
#  ('Allentown, PA', 'Las Vegas, NV', 2951.57),
#  ('Allentown, PA', 'Memphis, TN', 1051.79),
#  ('Allentown, PA', 'Nashville, TN', 867.2),
#  ('Allentown, PA', 'Oklahoma City, OK', 1533.85),
#  ('Allentown, PA', 'Omaha, NE', 1473.59),
#  ('Allentown, PA', 'Reno, NV', 3183.56),
#  ('Allentown, PA', 'Round Rock, TX', 1697.31),
#  ('Allentown, PA', 'West Sacramento, CA', 3318.25),
#  ('Allentown, PA', 'San Antonio, TX', 1810.08),
#  ('Allentown, PA', 'Salt Lake City, UT', 2785.11),
#  ('Allentown, PA', 'Tacoma, WA', 3353.47),
#  ('Allentown, PA', 'Wichita, KS', 1533.74),
#  ('Allentown, PA', 'Baltimore, MD', 140.91),
#  ('Allentown, PA', 'Boston, MA', 362.66),
#  ('Allentown, PA', 'New York City, NY', 100.61),
#  ('Allentown, PA', 'St. Petersburg, FL', 1128.08),
#  ('Allentown, PA', 'Chicago, IL', 862.73),
#  ('Allentown, PA', 'Cleveland, OH', 494.43),
#  ('Allentown, PA', 'Detroit, MI', 668.73),
#  ('Allentown, PA', 'Kansas City, MO', 1337.96),
#  ('Allentown, PA', 'Minneapolis, MN', 1313.34),
#  ('Allentown, PA', 'Houston, TX', 1775.38),
#  ('Allentown, PA', 'Anaheim, CA', 3014.08),
#  ('Allentown, PA', 'Oakland, CA', 3401.32),
#  ('Allentown, PA', 'Seattle, WA', 3340.56),
#  ('Allentown, PA', 'Arlington, TX', 1535.52),
#  ('Allentown, PA', 'Atlanta, GA', 803.87),
#  ('Allentown, PA', 'Miami, FL', 1252.98),
#  ('Allentown, PA', 'Philadelphia, PA', 58.95),
#  ('Allentown, PA', 'Washington, D.C., DC', 189.77),
#  ('Allentown, PA', 'Cincinnati, OH', 574.17),
#  ('Allentown, PA', 'Milwaukee, WI', 952.09),
#  ('Allentown, PA', 'Pittsburgh, PA', 287.13),
#  ('Allentown, PA', 'St. Louis, MO', 1125.15),
#  ('Allentown, PA', 'Phoenix, AZ', 2651.41),
#  ('Allentown, PA', 'Denver, CO', 1931.51),
#  ('Allentown, PA', 'Los Angeles, CA', 3024.99),
#  ('Allentown, PA', 'San Diego, CA', 2946.27),
#  ('Allentown, PA', 'San Francisco, CA', 3412.15),
#  ('Louisville, KY', 'Buffalo, NY', 656.26),
#  ('Louisville, KY', 'Charlotte, NC', 520.24),
#  ('Louisville, KY', 'Columbus, OH', 351.39),
#  ('Louisville, KY', 'Durham, NC', 544.68),
#  ('Louisville, KY', 'Indianapolis, IN', 114.1),
#  ('Louisville, KY', 'Allentown, PA', 930.77),
#  ('Louisville, KY', 'Louisville, KY', 0),
#  ('Louisville, KY', 'Norfolk, VA', 678.09),
#  ('Louisville, KY', 'Pawtucket, RI', 1166.18),
#  ('Louisville, KY', 'Rochester, NY', 751.39),
#  ('Louisville, KY', 'Scranton, PA', 861.6),
#  ('Louisville, KY', 'Syracuse, NY', 826.11),
#  ('Louisville, KY', 'Toledo, OH', 335.13),
#  ('Louisville, KY', 'Albuquerque, NM', 1541.57),
#  ('Louisville, KY', 'El Paso, TX', 1539.5),
#  ('Louisville, KY', 'Fresno, CA', 2578.02),
#  ('Louisville, KY', 'Des Moines, IA', 668.49),
#  ('Louisville, KY', 'Las Vegas, NV', 2276.28),
#  ('Louisville, KY', 'Memphis, TN', 376.5),
#  ('Louisville, KY', 'Nashville, TN', 193.21),
#  ('Louisville, KY', 'Oklahoma City, OK', 858.57),
#  ('Louisville, KY', 'Omaha, NE', 778.71),
#  ('Louisville, KY', 'Reno, NV', 2616.63),
#  ('Louisville, KY', 'Round Rock, TX', 1022.02),
#  ('Louisville, KY', 'West Sacramento, CA', 2740.51),
#  ('Louisville, KY', 'San Antonio, TX', 1134.79),
#  ('Louisville, KY', 'Salt Lake City, UT', 2218.19),
#  ('Louisville, KY', 'Tacoma, WA', 2786.54),
#  ('Louisville, KY', 'Wichita, KS', 838.87),
#  ('Louisville, KY', 'Baltimore, MD', 641.93),
#  ('Louisville, KY', 'Boston, MA', 1207.03),
#  ('Louisville, KY', 'New York City, NY', 993.56),
#  ('Louisville, KY', 'St. Petersburg, FL', 941.9),
#  ('Louisville, KY', 'Chicago, IL', 295.8),
#  ('Louisville, KY', 'Cleveland, OH', 442.5),
#  ('Louisville, KY', 'Detroit, MI', 395.84),
#  ('Louisville, KY', 'Kansas City, MO', 643.09),
#  ('Louisville, KY', 'Minneapolis, MN', 746.41),
#  ('Louisville, KY', 'Houston, TX', 1100.09),
#  ('Louisville, KY', 'Anaheim, CA', 2338.8),
#  ('Louisville, KY', 'Oakland, CA', 2726.03),
#  ('Louisville, KY', 'Seattle, WA', 2773.64),
#  ('Louisville, KY', 'Arlington, TX', 860.24),
#  ('Louisville, KY', 'Atlanta, GA', 465.67),
#  ('Louisville, KY', 'Miami, FL', 1135.22),
#  ('Louisville, KY', 'Philadelphia, PA', 743.79),
#  ('Louisville, KY', 'Washington, D.C., DC', 600.3),
#  ('Louisville, KY', 'Cincinnati, OH', 161.08),
#  ('Louisville, KY', 'Milwaukee, WI', 385.17),
#  ('Louisville, KY', 'Pittsburgh, PA', 550.69),
#  ('Louisville, KY', 'St. Louis, MO', 423.3),
#  ('Louisville, KY', 'Phoenix, AZ', 1976.12),
#  ('Louisville, KY', 'Denver, CO', 1236.64),
#  ('Louisville, KY', 'Los Angeles, CA', 2349.71),
#  ('Louisville, KY', 'San Diego, CA', 2270.98),
#  ('Louisville, KY', 'San Francisco, CA', 2736.86),
#  ('Norfolk, VA', 'Buffalo, NY', 715.16),
#  ('Norfolk, VA', 'Charlotte, NC', 327.15),
#  ('Norfolk, VA', 'Columbus, OH', 592.48),
#  ('Norfolk, VA', 'Durham, NC', 184.05),
#  ('Norfolk, VA', 'Indianapolis, IN', 780.63),
#  ('Norfolk, VA', 'Allentown, PA', 320.79),
#  ('Norfolk, VA', 'Louisville, KY', 669.6),
#  ('Norfolk, VA', 'Norfolk, VA', 0),
#  ('Norfolk, VA', 'Pawtucket, RI', 579.3),
#  ('Norfolk, VA', 'Rochester, NY', 626.85),
#  ('Norfolk, VA', 'Scranton, PA', 382.96),
#  ('Norfolk, VA', 'Syracuse, NY', 515.14),
#  ('Norfolk, VA', 'Toledo, OH', 683.79),
#  ('Norfolk, VA', 'Albuquerque, NM', 2162.57),
#  ('Norfolk, VA', 'El Paso, TX', 2160.5),
#  ('Norfolk, VA', 'Fresno, CA', 3199.02),
#  ('Norfolk, VA', 'Des Moines, IA', 1335.02),
#  ('Norfolk, VA', 'Las Vegas, NV', 2897.28),
#  ('Norfolk, VA', 'Memphis, TN', 997.5),
#  ('Norfolk, VA', 'Nashville, TN', 766.61),
#  ('Norfolk, VA', 'Oklahoma City, OK', 1479.57),
#  ('Norfolk, VA', 'Omaha, NE', 1445.24),
#  ('Norfolk, VA', 'Reno, NV', 3283.16),
#  ('Norfolk, VA', 'Round Rock, TX', 1643.02),
#  ('Norfolk, VA', 'West Sacramento, CA', 3361.51),
#  ('Norfolk, VA', 'San Antonio, TX', 1755.79),
#  ('Norfolk, VA', 'Salt Lake City, UT', 2884.71),
#  ('Norfolk, VA', 'Tacoma, WA', 3453.07),
#  ('Norfolk, VA', 'Wichita, KS', 1412.71),
#  ('Norfolk, VA', 'Baltimore, MD', 252.07),
#  ('Norfolk, VA', 'Boston, MA', 620.15),
#  ('Norfolk, VA', 'New York City, NY', 358.1),
#  ('Norfolk, VA', 'St. Petersburg, FL', 847.21),
#  ('Norfolk, VA', 'Chicago, IL', 962.33),
#  ('Norfolk, VA', 'Cleveland, OH', 565.97),
#  ('Norfolk, VA', 'Detroit, MI', 737.33),
#  ('Norfolk, VA', 'Kansas City, MO', 1309.61),
#  ('Norfolk, VA', 'Minneapolis, MN', 1412.93),
#  ('Norfolk, VA', 'Houston, TX', 1721.09),
#  ('Norfolk, VA', 'Anaheim, CA', 2959.8),
#  ('Norfolk, VA', 'Oakland, CA', 3347.04),
#  ('Norfolk, VA', 'Seattle, WA', 3440.16),
#  ('Norfolk, VA', 'Arlington, TX', 1481.24),
#  ('Norfolk, VA', 'Atlanta, GA', 616.71),
#  ('Norfolk, VA', 'Miami, FL', 972.12),
#  ('Norfolk, VA', 'Philadelphia, PA', 276.52),
#  ('Norfolk, VA', 'Washington, D.C., DC', 206.54),
#  ('Norfolk, VA', 'Cincinnati, OH', 629.95),
#  ('Norfolk, VA', 'Milwaukee, WI', 1051.69),
#  ('Norfolk, VA', 'Pittsburgh, PA', 417.41),
#  ('Norfolk, VA', 'St. Louis, MO', 1044.3),
#  ('Norfolk, VA', 'Phoenix, AZ', 2597.13),
#  ('Norfolk, VA', 'Denver, CO', 2435.84),
#  ('Norfolk, VA', 'Los Angeles, CA', 2970.71),
#  ('Norfolk, VA', 'San Diego, CA', 2891.99),
#  ('Norfolk, VA', 'San Francisco, CA', 3357.87),
#  ('Pawtucket, RI', 'Buffalo, NY', 635.31),
#  ('Pawtucket, RI', 'Charlotte, NC', 850.73),
#  ('Pawtucket, RI', 'Columbus, OH', 898.86),
#  ('Pawtucket, RI', 'Durham, NC', 704.7),
#  ('Pawtucket, RI', 'Indianapolis, IN', 1055.54),
#  ('Pawtucket, RI', 'Allentown, PA', 320.22),
#  ('Pawtucket, RI', 'Louisville, KY', 1160.1),
#  ('Pawtucket, RI', 'Norfolk, VA', 577.44),
#  ('Pawtucket, RI', 'Pawtucket, RI', 0),
#  ('Pawtucket, RI', 'Rochester, NY', 426.84),
#  ('Pawtucket, RI', 'Scranton, PA', 338.67),
#  ('Pawtucket, RI', 'Syracuse, NY', 345.96),
#  ('Pawtucket, RI', 'Toledo, OH', 844.25),
#  ('Pawtucket, RI', 'Albuquerque, NM', 2534.33),
#  ('Pawtucket, RI', 'El Paso, TX', 2532.25),
#  ('Pawtucket, RI', 'Fresno, CA', 3570.77),
#  ('Pawtucket, RI', 'Des Moines, IA', 1592.42),
#  ('Pawtucket, RI', 'Las Vegas, NV', 3269.04),
#  ('Pawtucket, RI', 'Memphis, TN', 1369.26),
#  ('Pawtucket, RI', 'Nashville, TN', 1184.66),
#  ('Pawtucket, RI', 'Oklahoma City, OK', 1851.32),
#  ('Pawtucket, RI', 'Omaha, NE', 1702.65),
#  ('Pawtucket, RI', 'Reno, NV', 3412.62),
#  ('Pawtucket, RI', 'Round Rock, TX', 2014.77),
#  ('Pawtucket, RI', 'West Sacramento, CA', 3547.31),
#  ('Pawtucket, RI', 'San Antonio, TX', 2127.54),
#  ('Pawtucket, RI', 'Salt Lake City, UT', 3014.17),
#  ('Pawtucket, RI', 'Tacoma, WA', 3582.53),
#  ('Pawtucket, RI', 'Wichita, KS', 1762.8),
#  ('Pawtucket, RI', 'Baltimore, MD', 407.63),
#  ('Pawtucket, RI', 'Boston, MA', 41.6),
#  ('Pawtucket, RI', 'New York City, NY', 224.04),
#  ('Pawtucket, RI', 'St. Petersburg, FL', 1390.36),
#  ('Pawtucket, RI', 'Chicago, IL', 1091.78),
#  ('Pawtucket, RI', 'Cleveland, OH', 723.49),
#  ('Pawtucket, RI', 'Detroit, MI', 897.79),
#  ('Pawtucket, RI', 'Kansas City, MO', 1567.02),
#  ('Pawtucket, RI', 'Minneapolis, MN', 1542.39),
#  ('Pawtucket, RI', 'Houston, TX', 2092.84),
#  ('Pawtucket, RI', 'Anaheim, CA', 3331.55),
#  ('Pawtucket, RI', 'Oakland, CA', 3625.53),
#  ('Pawtucket, RI', 'Seattle, WA', 3569.62),
#  ('Pawtucket, RI', 'Arlington, TX', 1852.99),
#  ('Pawtucket, RI', 'Atlanta, GA', 1092.19),
#  ('Pawtucket, RI', 'Miami, FL', 1515.26),
#  ('Pawtucket, RI', 'Philadelphia, PA', 314.1),
#  ('Pawtucket, RI', 'Washington, D.C., DC', 451.75),
#  ('Pawtucket, RI', 'Cincinnati, OH', 1004.01),
#  ('Pawtucket, RI', 'Milwaukee, WI', 1181.15),
#  ('Pawtucket, RI', 'Pittsburgh, PA', 604.6),
#  ('Pawtucket, RI', 'St. Louis, MO', 1354.2),
#  ('Pawtucket, RI', 'Phoenix, AZ', 2968.88),
#  ('Pawtucket, RI', 'Denver, CO', 2160.57),
#  ('Pawtucket, RI', 'Los Angeles, CA', 3342.46),
#  ('Pawtucket, RI', 'San Diego, CA', 3263.74),
#  ('Pawtucket, RI', 'San Francisco, CA', 3631.15),
#  ('Rochester, NY', 'Buffalo, NY', 71.7),
#  ('Rochester, NY', 'Charlotte, NC', 891.45),
#  ('Rochester, NY', 'Columbus, OH', 484.02),
#  ('Rochester, NY', 'Durham, NC', 715.61),
#  ('Rochester, NY', 'Indianapolis, IN', 640.7),
#  ('Rochester, NY', 'Allentown, PA', 310.23),
#  ('Rochester, NY', 'Louisville, KY', 745.26),
#  ('Rochester, NY', 'Norfolk, VA', 601.4),
#  ('Rochester, NY', 'Pawtucket, RI', 433.51),
#  ('Rochester, NY', 'Rochester, NY', 0),
#  ('Rochester, NY', 'Scranton, PA', 241.06),
#  ('Rochester, NY', 'Syracuse, NY', 85.39),
#  ('Rochester, NY', 'Toledo, OH', 429.41),
#  ('Rochester, NY', 'Albuquerque, NM', 2284.6),
#  ('Rochester, NY', 'El Paso, TX', 2282.53),
#  ('Rochester, NY', 'Fresno, CA', 3321.05),
#  ('Rochester, NY', 'Des Moines, IA', 1177.58),
#  ('Rochester, NY', 'Las Vegas, NV', 3019.31),
#  ('Rochester, NY', 'Memphis, TN', 1119.54),
#  ('Rochester, NY', 'Nashville, TN', 936.24),
#  ('Rochester, NY', 'Oklahoma City, OK', 1601.6),
#  ('Rochester, NY', 'Omaha, NE', 1287.8),
#  ('Rochester, NY', 'Reno, NV', 2997.78),
#  ('Rochester, NY', 'Round Rock, TX', 1765.05),
#  ('Rochester, NY', 'West Sacramento, CA', 3132.47),
#  ('Rochester, NY', 'San Antonio, TX', 1877.82),
#  ('Rochester, NY', 'Salt Lake City, UT', 2599.33),
#  ('Rochester, NY', 'Tacoma, WA', 3167.69),
#  ('Rochester, NY', 'Wichita, KS', 1347.96),
#  ('Rochester, NY', 'Baltimore, MD', 353.08),
#  ('Rochester, NY', 'Boston, MA', 407.47),
#  ('Rochester, NY', 'New York City, NY', 373.02),
#  ('Rochester, NY', 'St. Petersburg, FL', 1484.97),
#  ('Rochester, NY', 'Chicago, IL', 676.94),
#  ('Rochester, NY', 'Cleveland, OH', 308.65),
#  ('Rochester, NY', 'Detroit, MI', 482.95),
#  ('Rochester, NY', 'Kansas City, MO', 1152.17),
#  ('Rochester, NY', 'Minneapolis, MN', 1127.55),
#  ('Rochester, NY', 'Houston, TX', 1843.12),
#  ('Rochester, NY', 'Anaheim, CA', 3081.83),
#  ('Rochester, NY', 'Oakland, CA', 3210.68),
#  ('Rochester, NY', 'Seattle, WA', 3154.78),
#  ('Rochester, NY', 'Arlington, TX', 1603.27),
#  ('Rochester, NY', 'Atlanta, GA', 1131.93),
#  ('Rochester, NY', 'Miami, FL', 1609.87),
#  ('Rochester, NY', 'Philadelphia, PA', 354.8),
#  ('Rochester, NY', 'Washington, D.C., DC', 398.65),
#  ('Rochester, NY', 'Cincinnati, OH', 589.17),
#  ('Rochester, NY', 'Milwaukee, WI', 766.31),
#  ('Rochester, NY', 'Pittsburgh, PA', 386.75),
#  ('Rochester, NY', 'St. Louis, MO', 939.36),
#  ('Rochester, NY', 'Phoenix, AZ', 2719.16),
#  ('Rochester, NY', 'Denver, CO', 1745.73),
#  ('Rochester, NY', 'Los Angeles, CA', 3092.74),
#  ('Rochester, NY', 'San Diego, CA', 3014.02),
#  ('Rochester, NY', 'San Francisco, CA', 3216.31),
#  ('Scranton, PA', 'Buffalo, NY', 330.34),
#  ('Scranton, PA', 'Charlotte, NC', 591.93),
#  ('Scranton, PA', 'Columbus, OH', 593.89),
#  ('Scranton, PA', 'Durham, NC', 510.6),
#  ('Scranton, PA', 'Indianapolis, IN', 750.57),
#  ('Scranton, PA', 'Allentown, PA', 73.78),
#  ('Scranton, PA', 'Louisville, KY', 855.13),
#  ('Scranton, PA', 'Norfolk, VA', 381.67),
#  ('Scranton, PA', 'Pawtucket, RI', 323.75),
#  ('Scranton, PA', 'Rochester, NY', 242.03),
#  ('Scranton, PA', 'Scranton, PA', 0),
#  ('Scranton, PA', 'Syracuse, NY', 130.73),
#  ('Scranton, PA', 'Toledo, OH', 539.28),
#  ('Scranton, PA', 'Albuquerque, NM', 2394.47),
#  ('Scranton, PA', 'El Paso, TX', 2392.4),
#  ('Scranton, PA', 'Fresno, CA', 3430.92),
#  ('Scranton, PA', 'Des Moines, IA', 1287.45),
#  ('Scranton, PA', 'Las Vegas, NV', 3129.18),
#  ('Scranton, PA', 'Memphis, TN', 1229.41),
#  ('Scranton, PA', 'Nashville, TN', 1046.11),
#  ('Scranton, PA', 'Oklahoma City, OK', 1711.47),
#  ('Scranton, PA', 'Omaha, NE', 1397.67),
#  ('Scranton, PA', 'Reno, NV', 3107.65),
#  ('Scranton, PA', 'Round Rock, TX', 1874.92),
#  ('Scranton, PA', 'West Sacramento, CA', 3242.34),
#  ('Scranton, PA', 'San Antonio, TX', 1987.69),
#  ('Scranton, PA', 'Salt Lake City, UT', 2709.2),
#  ('Scranton, PA', 'Tacoma, WA', 3277.56),
#  ('Scranton, PA', 'Wichita, KS', 1457.83),
#  ('Scranton, PA', 'Baltimore, MD', 209.09),
#  ('Scranton, PA', 'Boston, MA', 364.61),
#  ('Scranton, PA', 'New York City, NY', 139.32),
#  ('Scranton, PA', 'St. Petersburg, FL', 1196.25),
#  ('Scranton, PA', 'Chicago, IL', 786.81),
#  ('Scranton, PA', 'Cleveland, OH', 418.52),
#  ('Scranton, PA', 'Detroit, MI', 592.82),
#  ('Scranton, PA', 'Kansas City, MO', 1262.04),
#  ('Scranton, PA', 'Minneapolis, MN', 1237.42),
#  ('Scranton, PA', 'Houston, TX', 1952.99),
#  ('Scranton, PA', 'Anaheim, CA', 3191.7),
#  ('Scranton, PA', 'Oakland, CA', 3320.55),
#  ('Scranton, PA', 'Seattle, WA', 3264.65),
#  ('Scranton, PA', 'Arlington, TX', 1713.14),
#  ('Scranton, PA', 'Atlanta, GA', 833.4),
#  ('Scranton, PA', 'Miami, FL', 1321.16),
#  ('Scranton, PA', 'Philadelphia, PA', 122.0),
#  ('Scranton, PA', 'Washington, D.C., DC', 257.95),
#  ('Scranton, PA', 'Cincinnati, OH', 699.04),
#  ('Scranton, PA', 'Milwaukee, WI', 876.18),
#  ('Scranton, PA', 'Pittsburgh, PA', 496.62),
#  ('Scranton, PA', 'St. Louis, MO', 1049.23),
#  ('Scranton, PA', 'Phoenix, AZ', 2829.03),
#  ('Scranton, PA', 'Denver, CO', 1855.6),
#  ('Scranton, PA', 'Los Angeles, CA', 3202.61),
#  ('Scranton, PA', 'San Diego, CA', 3123.89),
#  ('Scranton, PA', 'San Francisco, CA', 3326.18),
#  ('Syracuse, NY', 'Buffalo, NY', 149.87),
#  ('Syracuse, NY', 'Charlotte, NC', 968.41),
#  ('Syracuse, NY', 'Columbus, OH', 560.98),
#  ('Syracuse, NY', 'Durham, NC', 641.72),
#  ('Syracuse, NY', 'Indianapolis, IN', 717.66),
#  ('Syracuse, NY', 'Allentown, PA', 208.27),
#  ('Syracuse, NY', 'Louisville, KY', 822.22),
#  ('Syracuse, NY', 'Norfolk, VA', 516.15),
#  ('Syracuse, NY', 'Pawtucket, RI', 346.64),
#  ('Syracuse, NY', 'Rochester, NY', 85.24),
#  ('Syracuse, NY', 'Scranton, PA', 133.32),
#  ('Syracuse, NY', 'Syracuse, NY', 0),
#  ('Syracuse, NY', 'Toledo, OH', 506.37),
#  ('Syracuse, NY', 'Albuquerque, NM', 2361.56),
#  ('Syracuse, NY', 'El Paso, TX', 2359.49),
#  ('Syracuse, NY', 'Fresno, CA', 3398.01),
#  ('Syracuse, NY', 'Des Moines, IA', 1254.54),
#  ('Syracuse, NY', 'Las Vegas, NV', 3096.27),
#  ('Syracuse, NY', 'Memphis, TN', 1196.5),
#  ('Syracuse, NY', 'Nashville, TN', 1013.2),
#  ('Syracuse, NY', 'Oklahoma City, OK', 1678.56),
#  ('Syracuse, NY', 'Omaha, NE', 1364.76),
#  ('Syracuse, NY', 'Reno, NV', 3074.74),
#  ('Syracuse, NY', 'Round Rock, TX', 1842.01),
#  ('Syracuse, NY', 'West Sacramento, CA', 3209.43),
#  ('Syracuse, NY', 'San Antonio, TX', 1954.78),
#  ('Syracuse, NY', 'Salt Lake City, UT', 2676.29),
#  ('Syracuse, NY', 'Tacoma, WA', 3244.65),
#  ('Syracuse, NY', 'Wichita, KS', 1424.92),
#  ('Syracuse, NY', 'Baltimore, MD', 343.57),
#  ('Syracuse, NY', 'Boston, MA', 320.6),
#  ('Syracuse, NY', 'New York City, NY', 264.05),
#  ('Syracuse, NY', 'St. Petersburg, FL', 1561.93),
#  ('Syracuse, NY', 'Chicago, IL', 753.9),
#  ('Syracuse, NY', 'Cleveland, OH', 385.61),
#  ('Syracuse, NY', 'Detroit, MI', 559.91),
#  ('Syracuse, NY', 'Kansas City, MO', 1229.13),
#  ('Syracuse, NY', 'Minneapolis, MN', 1204.51),
#  ('Syracuse, NY', 'Houston, TX', 1920.08),
#  ('Syracuse, NY', 'Anaheim, CA', 3158.79),
#  ('Syracuse, NY', 'Oakland, CA', 3287.64),
#  ('Syracuse, NY', 'Seattle, WA', 3231.74),
#  ('Syracuse, NY', 'Arlington, TX', 1680.23),
#  ('Syracuse, NY', 'Atlanta, GA', 1208.89),
#  ('Syracuse, NY', 'Miami, FL', 1686.83),
#  ('Syracuse, NY', 'Philadelphia, PA', 256.48),
#  ('Syracuse, NY', 'Washington, D.C., DC', 389.07),
#  ('Syracuse, NY', 'Cincinnati, OH', 666.13),
#  ('Syracuse, NY', 'Milwaukee, WI', 843.27),
#  ('Syracuse, NY', 'Pittsburgh, PA', 463.71),
#  ('Syracuse, NY', 'St. Louis, MO', 1016.32),
#  ('Syracuse, NY', 'Phoenix, AZ', 2796.12),
#  ('Syracuse, NY', 'Denver, CO', 1822.69),
#  ('Syracuse, NY', 'Los Angeles, CA', 3169.7),
#  ('Syracuse, NY', 'San Diego, CA', 3090.98),
#  ('Syracuse, NY', 'San Francisco, CA', 3293.27),
#  ('Toledo, OH', 'Buffalo, NY', 335.17),
#  ('Toledo, OH', 'Charlotte, NC', 591.75),
#  ('Toledo, OH', 'Columbus, OH', 152.32),
#  ('Toledo, OH', 'Durham, NC', 660.53),
#  ('Toledo, OH', 'Indianapolis, IN', 226.39),
#  ('Toledo, OH', 'Allentown, PA', 609.69),
#  ('Toledo, OH', 'Louisville, KY', 330.95),
#  ('Toledo, OH', 'Norfolk, VA', 733.48),
#  ('Toledo, OH', 'Pawtucket, RI', 845.09),
#  ('Toledo, OH', 'Rochester, NY', 430.31),
#  ('Toledo, OH', 'Scranton, PA', 540.51),
#  ('Toledo, OH', 'Syracuse, NY', 505.03),
#  ('Toledo, OH', 'Toledo, OH', 0),
#  ('Toledo, OH', 'Albuquerque, NM', 1870.3),
#  ('Toledo, OH', 'El Paso, TX', 1868.22),
#  ('Toledo, OH', 'Fresno, CA', 2906.75),
#  ('Toledo, OH', 'Des Moines, IA', 763.28),
#  ('Toledo, OH', 'Las Vegas, NV', 2605.01),
#  ('Toledo, OH', 'Memphis, TN', 705.23),
#  ('Toledo, OH', 'Nashville, TN', 521.94),
#  ('Toledo, OH', 'Oklahoma City, OK', 1187.29),
#  ('Toledo, OH', 'Omaha, NE', 873.5),
#  ('Toledo, OH', 'Reno, NV', 2583.47),
#  ('Toledo, OH', 'Round Rock, TX', 1350.75),
#  ('Toledo, OH', 'West Sacramento, CA', 2718.16),
#  ('Toledo, OH', 'San Antonio, TX', 1463.52),
#  ('Toledo, OH', 'Salt Lake City, UT', 2185.02),
#  ('Toledo, OH', 'Tacoma, WA', 2753.38),
#  ('Toledo, OH', 'Wichita, KS', 933.65),
#  ('Toledo, OH', 'Baltimore, MD', 564.41),
#  ('Toledo, OH', 'Boston, MA', 885.95),
#  ('Toledo, OH', 'New York City, NY', 672.47),
#  ('Toledo, OH', 'St. Petersburg, FL', 1270.63),
#  ('Toledo, OH', 'Chicago, IL', 262.64),
#  ('Toledo, OH', 'Cleveland, OH', 121.42),
#  ('Toledo, OH', 'Detroit, MI', 58.64),
#  ('Toledo, OH', 'Kansas City, MO', 737.87),
#  ('Toledo, OH', 'Minneapolis, MN', 713.24),
#  ('Toledo, OH', 'Houston, TX', 1428.82),
#  ('Toledo, OH', 'Anaheim, CA', 2667.52),
#  ('Toledo, OH', 'Oakland, CA', 2796.38),
#  ('Toledo, OH', 'Seattle, WA', 2740.47),
#  ('Toledo, OH', 'Arlington, TX', 1188.96),
#  ('Toledo, OH', 'Atlanta, GA', 794.4),
#  ('Toledo, OH', 'Miami, FL', 1463.95),
#  ('Toledo, OH', 'Philadelphia, PA', 654.25),
#  ('Toledo, OH', 'Washington, D.C., DC', 565.11),
#  ('Toledo, OH', 'Cincinnati, OH', 308.98),
#  ('Toledo, OH', 'Milwaukee, WI', 352.0),
#  ('Toledo, OH', 'Pittsburgh, PA', 313.24),
#  ('Toledo, OH', 'St. Louis, MO', 525.06),
#  ('Toledo, OH', 'Phoenix, AZ', 2304.85),
#  ('Toledo, OH', 'Denver, CO', 1331.42),
#  ('Toledo, OH', 'Los Angeles, CA', 2678.43),
#  ('Toledo, OH', 'San Diego, CA', 2599.71),
#  ('Toledo, OH', 'San Francisco, CA', 2802.0),
#  ('Albuquerque, NM', 'Buffalo, NY', 2208.77),
#  ('Albuquerque, NM', 'Charlotte, NC', 1787.42),
#  ('Albuquerque, NM', 'Columbus, OH', 1844.41),
#  ('Albuquerque, NM', 'Durham, NC', 2025.12),
#  ('Albuquerque, NM', 'Indianapolis, IN', 1666.62),
#  ('Albuquerque, NM', 'Allentown, PA', 2214.88),
#  ('Albuquerque, NM', 'Louisville, KY', 1538.29),
#  ('Albuquerque, NM', 'Norfolk, VA', 2158.53),
#  ('Albuquerque, NM', 'Pawtucket, RI', 2558.85),
#  ('Albuquerque, NM', 'Rochester, NY', 2303.91),
#  ('Albuquerque, NM', 'Scranton, PA', 2414.11),
#  ('Albuquerque, NM', 'Syracuse, NY', 2378.63),
#  ('Albuquerque, NM', 'Toledo, OH', 1887.65),
#  ('Albuquerque, NM', 'Albuquerque, NM', 0),
#  ('Albuquerque, NM', 'El Paso, TX', 265.94),
#  ('Albuquerque, NM', 'Fresno, CA', 925.7),
#  ('Albuquerque, NM', 'Des Moines, IA', 1076.66),
#  ('Albuquerque, NM', 'Las Vegas, NV', 574.08),
#  ('Albuquerque, NM', 'Memphis, TN', 1199.39),
#  ('Albuquerque, NM', 'Nashville, TN', 1415.13),
#  ('Albuquerque, NM', 'Oklahoma City, OK', 546.41),
#  ('Albuquerque, NM', 'Omaha, NE', 945.09),
#  ('Albuquerque, NM', 'Reno, NV', 1019.26),
#  ('Albuquerque, NM', 'Round Rock, TX', 773.48),
#  ('Albuquerque, NM', 'West Sacramento, CA', 1093.73),
#  ('Albuquerque, NM', 'San Antonio, TX', 820.24),
#  ('Albuquerque, NM', 'Salt Lake City, UT', 621.36),
#  ('Albuquerque, NM', 'Tacoma, WA', 1519.94),
#  ('Albuquerque, NM', 'Wichita, KS', 623.0),
#  ('Albuquerque, NM', 'Baltimore, MD', 2122.36),
#  ('Albuquerque, NM', 'Boston, MA', 2599.71),
#  ('Albuquerque, NM', 'New York City, NY', 2313.52),
#  ('Albuquerque, NM', 'St. Petersburg, FL', 1874.19),
#  ('Albuquerque, NM', 'Chicago, IL', 1643.28),
#  ('Albuquerque, NM', 'Cleveland, OH', 1995.01),
#  ('Albuquerque, NM', 'Detroit, MI', 1948.35),
#  ('Albuquerque, NM', 'Kansas City, MO', 960.38),
#  ('Albuquerque, NM', 'Minneapolis, MN', 1329.29),
#  ('Albuquerque, NM', 'Houston, TX', 921.82),
#  ('Albuquerque, NM', 'Anaheim, CA', 813.62),
#  ('Albuquerque, NM', 'Oakland, CA', 1093.39),
#  ('Albuquerque, NM', 'Seattle, WA', 1507.04),
#  ('Albuquerque, NM', 'Arlington, TX', 676.57),
#  ('Albuquerque, NM', 'Atlanta, GA', 1546.63),
#  ('Albuquerque, NM', 'Miami, FL', 2057.4),
#  ('Albuquerque, NM', 'Philadelphia, PA', 2224.22),
#  ('Albuquerque, NM', 'Washington, D.C., DC', 2080.73),
#  ('Albuquerque, NM', 'Cincinnati, OH', 1658.11),
#  ('Albuquerque, NM', 'Milwaukee, WI', 1732.64),
#  ('Albuquerque, NM', 'Pittsburgh, PA', 1981.97),
#  ('Albuquerque, NM', 'St. Louis, MO', 1349.86),
#  ('Albuquerque, NM', 'Phoenix, AZ', 450.95),
#  ('Albuquerque, NM', 'Denver, CO', 447.0),
#  ('Albuquerque, NM', 'Los Angeles, CA', 824.53),
#  ('Albuquerque, NM', 'San Diego, CA', 857.58),
#  ('Albuquerque, NM', 'San Francisco, CA', 1104.22),
#  ('El Paso, TX', 'Buffalo, NY', 2206.64),
#  ('El Paso, TX', 'Charlotte, NC', 1785.29),
#  ('El Paso, TX', 'Columbus, OH', 1842.28),
#  ('El Paso, TX', 'Durham, NC', 2022.98),
#  ('El Paso, TX', 'Indianapolis, IN', 1664.48),
#  ('El Paso, TX', 'Allentown, PA', 2212.74),
#  ('El Paso, TX', 'Louisville, KY', 1536.15),
#  ('El Paso, TX', 'Norfolk, VA', 2156.39),
#  ('El Paso, TX', 'Pawtucket, RI', 2556.71),
#  ('El Paso, TX', 'Rochester, NY', 2301.77),
#  ('El Paso, TX', 'Scranton, PA', 2411.97),
#  ('El Paso, TX', 'Syracuse, NY', 2376.49),
#  ('El Paso, TX', 'Toledo, OH', 1885.51),
#  ('El Paso, TX', 'Albuquerque, NM', 276.19),
#  ('El Paso, TX', 'El Paso, TX', 0),
#  ('El Paso, TX', 'Fresno, CA', 1040.94),
#  ('El Paso, TX', 'Des Moines, IA', 1427.24),
#  ('El Paso, TX', 'Las Vegas, NV', 739.2),
#  ('El Paso, TX', 'Memphis, TN', 1197.25),
#  ('El Paso, TX', 'Nashville, TN', 1412.99),
#  ('El Paso, TX', 'Oklahoma City, OK', 844.05),
#  ('El Paso, TX', 'Omaha, NE', 1300.2),
#  ('El Paso, TX', 'Reno, NV', 1184.38),
#  ('El Paso, TX', 'Round Rock, TX', 625.01),
#  ('El Paso, TX', 'West Sacramento, CA', 1203.43),
#  ('El Paso, TX', 'San Antonio, TX', 551.28),
#  ('El Paso, TX', 'Salt Lake City, UT', 874.85),
#  ('El Paso, TX', 'Tacoma, WA', 1773.44),
#  ('El Paso, TX', 'Wichita, KS', 1005.56),
#  ('El Paso, TX', 'Baltimore, MD', 2120.23),
#  ('El Paso, TX', 'Boston, MA', 2597.57),
#  ('El Paso, TX', 'New York City, NY', 2311.39),
#  ('El Paso, TX', 'St. Petersburg, FL', 1872.05),
#  ('El Paso, TX', 'Chicago, IL', 1641.14),
#  ('El Paso, TX', 'Cleveland, OH', 1992.88),
#  ('El Paso, TX', 'Detroit, MI', 1946.21),
#  ('El Paso, TX', 'Kansas City, MO', 1226.82),
#  ('El Paso, TX', 'Minneapolis, MN', 2091.75),
#  ('El Paso, TX', 'Houston, TX', 919.69),
#  ('El Paso, TX', 'Anaheim, CA', 801.71),
#  ('El Paso, TX', 'Oakland, CA', 1188.95),
#  ('El Paso, TX', 'Seattle, WA', 1760.53),
#  ('El Paso, TX', 'Arlington, TX', 674.44),
#  ('El Paso, TX', 'Atlanta, GA', 1544.5),
#  ('El Paso, TX', 'Miami, FL', 2055.27),
#  ('El Paso, TX', 'Philadelphia, PA', 2222.09),
#  ('El Paso, TX', 'Washington, D.C., DC', 2078.6),
#  ('El Paso, TX', 'Cincinnati, OH', 1655.97),
#  ('El Paso, TX', 'Milwaukee, WI', 1730.51),
#  ('El Paso, TX', 'Pittsburgh, PA', 1979.84),
#  ('El Paso, TX', 'St. Louis, MO', 1347.72),
#  ('El Paso, TX', 'Phoenix, AZ', 439.04),
#  ('El Paso, TX', 'Denver, CO', 721.54),
#  ('El Paso, TX', 'Los Angeles, CA', 812.62),
#  ('El Paso, TX', 'San Diego, CA', 733.9),
#  ('El Paso, TX', 'San Francisco, CA', 1199.78),
#  ('Fresno, CA', 'Buffalo, NY', 3240.53),
#  ('Fresno, CA', 'Charlotte, NC', 2819.18),
#  ('Fresno, CA', 'Columbus, OH', 2876.17),
#  ('Fresno, CA', 'Durham, NC', 3056.87),
#  ('Fresno, CA', 'Indianapolis, IN', 2698.37),
#  ('Fresno, CA', 'Allentown, PA', 3246.63),
#  ('Fresno, CA', 'Louisville, KY', 2570.04),
#  ('Fresno, CA', 'Norfolk, VA', 3190.28),
#  ('Fresno, CA', 'Pawtucket, RI', 3590.61),
#  ('Fresno, CA', 'Rochester, NY', 3335.66),
#  ('Fresno, CA', 'Scranton, PA', 3445.86),
#  ('Fresno, CA', 'Syracuse, NY', 3410.38),
#  ('Fresno, CA', 'Toledo, OH', 2919.4),
#  ('Fresno, CA', 'Albuquerque, NM', 923.96),
#  ('Fresno, CA', 'El Paso, TX', 1040.61),
#  ('Fresno, CA', 'Fresno, CA', 0),
#  ('Fresno, CA', 'Des Moines, IA', 1819.85),
#  ('Fresno, CA', 'Las Vegas, NV', 407.74),
#  ('Fresno, CA', 'Memphis, TN', 2231.14),
#  ('Fresno, CA', 'Nashville, TN', 2446.88),
#  ('Fresno, CA', 'Oklahoma City, OK', 1877.94),
#  ('Fresno, CA', 'Omaha, NE', 1688.28),
#  ('Fresno, CA', 'Reno, NV', 298.7),
#  ('Fresno, CA', 'Round Rock, TX', 1658.9),
#  ('Fresno, CA', 'West Sacramento, CA', 170.48),
#  ('Fresno, CA', 'San Antonio, TX', 1585.17),
#  ('Fresno, CA', 'Salt Lake City, UT', 697.64),
#  ('Fresno, CA', 'Tacoma, WA', 893.01),
#  ('Fresno, CA', 'Wichita, KS', 1544.61),
#  ('Fresno, CA', 'Baltimore, MD', 3154.12),
#  ('Fresno, CA', 'Boston, MA', 3631.46),
#  ('Fresno, CA', 'New York City, NY', 3345.28),
#  ('Fresno, CA', 'St. Petersburg, FL', 2905.94),
#  ('Fresno, CA', 'Chicago, IL', 2675.03),
#  ('Fresno, CA', 'Cleveland, OH', 3026.77),
#  ('Fresno, CA', 'Detroit, MI', 2980.1),
#  ('Fresno, CA', 'Kansas City, MO', 1755.09),
#  ('Fresno, CA', 'Minneapolis, MN', 2182.87),
#  ('Fresno, CA', 'Houston, TX', 1953.58),
#  ('Fresno, CA', 'Anaheim, CA', 262.85),
#  ('Fresno, CA', 'Oakland, CA', 181.58),
#  ('Fresno, CA', 'Seattle, WA', 924.35),
#  ('Fresno, CA', 'Arlington, TX', 1708.33),
#  ('Fresno, CA', 'Atlanta, GA', 2578.39),
#  ('Fresno, CA', 'Miami, FL', 3089.16),
#  ('Fresno, CA', 'Philadelphia, PA', 3255.98),
#  ('Fresno, CA', 'Washington, D.C., DC', 3112.49),
#  ('Fresno, CA', 'Cincinnati, OH', 2689.86),
#  ('Fresno, CA', 'Milwaukee, WI', 2764.4),
#  ('Fresno, CA', 'Pittsburgh, PA', 3013.73),
#  ('Fresno, CA', 'St. Louis, MO', 2381.61),
#  ('Fresno, CA', 'Phoenix, AZ', 601.52),
#  ('Fresno, CA', 'Denver, CO', 1154.5),
#  ('Fresno, CA', 'Los Angeles, CA', 224.7),
#  ('Fresno, CA', 'San Diego, CA', 360.11),
#  ('Fresno, CA', 'San Francisco, CA', 192.41),
#  ('Des Moines, IA', 'Buffalo, NY', 942.1),
#  ('Des Moines, IA', 'Charlotte, NC', 1131.12),
#  ('Des Moines, IA', 'Columbus, OH', 692.05),
#  ('Des Moines, IA', 'Durham, NC', 1155.57),
#  ('Des Moines, IA', 'Indianapolis, IN', 515.4),
#  ('Des Moines, IA', 'Allentown, PA', 1216.62),
#  ('Des Moines, IA', 'Louisville, KY', 630.31),
#  ('Des Moines, IA', 'Norfolk, VA', 1288.98),
#  ('Des Moines, IA', 'Pawtucket, RI', 1452.02),
#  ('Des Moines, IA', 'Rochester, NY', 1037.24),
#  ('Des Moines, IA', 'Scranton, PA', 1147.44),
#  ('Des Moines, IA', 'Syracuse, NY', 1111.96),
#  ('Des Moines, IA', 'Toledo, OH', 620.98),
#  ('Des Moines, IA', 'Albuquerque, NM', 1071.14),
#  ('Des Moines, IA', 'El Paso, TX', 1427.29),
#  ('Des Moines, IA', 'Fresno, CA', 1820.42),
#  ('Des Moines, IA', 'Des Moines, IA', 0),
#  ('Des Moines, IA', 'Las Vegas, NV', 1413.02),
#  ('Des Moines, IA', 'Memphis, TN', 690.31),
#  ('Des Moines, IA', 'Nashville, TN', 833.37),
#  ('Des Moines, IA', 'Oklahoma City, OK', 549.32),
#  ('Des Moines, IA', 'Omaha, NE', 135.0),
#  ('Des Moines, IA', 'Reno, NV', 2076.33),
#  ('Des Moines, IA', 'Round Rock, TX', 909.81),
#  ('Des Moines, IA', 'West Sacramento, CA', 2211.03),
#  ('Des Moines, IA', 'San Antonio, TX', 1022.58),
#  ('Des Moines, IA', 'Salt Lake City, UT', 1065.6),
#  ('Des Moines, IA', 'Tacoma, WA', 2246.24),
#  ('Des Moines, IA', 'Wichita, KS', 395.38),
#  ('Des Moines, IA', 'Baltimore, MD', 1090.52),
#  ('Des Moines, IA', 'Boston, MA', 1492.88),
#  ('Des Moines, IA', 'New York City, NY', 1279.4),
#  ('Des Moines, IA', 'St. Petersburg, FL', 1582.07),
#  ('Des Moines, IA', 'Chicago, IL', 363.93),
#  ('Des Moines, IA', 'Cleveland, OH', 728.34),
#  ('Des Moines, IA', 'Detroit, MI', 621.69),
#  ('Des Moines, IA', 'Kansas City, MO', 199.57),
#  ('Des Moines, IA', 'Minneapolis, MN', 244.2),
#  ('Des Moines, IA', 'Houston, TX', 987.88),
#  ('Des Moines, IA', 'Anaheim, CA', 1682.31),
#  ('Des Moines, IA', 'Oakland, CA', 2289.24),
#  ('Des Moines, IA', 'Seattle, WA', 2233.34),
#  ('Des Moines, IA', 'Arlington, TX', 748.03),
#  ('Des Moines, IA', 'Atlanta, GA', 1105.83),
#  ('Des Moines, IA', 'Miami, FL', 1775.39),
#  ('Des Moines, IA', 'Philadelphia, PA', 1261.18),
#  ('Des Moines, IA', 'Washington, D.C., DC', 1091.23),
#  ('Des Moines, IA', 'Cincinnati, OH', 623.58),
#  ('Des Moines, IA', 'Milwaukee, WI', 373.44),
#  ('Des Moines, IA', 'Pittsburgh, PA', 839.36),
#  ('Des Moines, IA', 'St. Louis, MO', 380.2),
#  ('Des Moines, IA', 'Phoenix, AZ', 1520.35),
#  ('Des Moines, IA', 'Denver, CO', 669.93),
#  ('Des Moines, IA', 'Los Angeles, CA', 1693.22),
#  ('Des Moines, IA', 'San Diego, CA', 1751.12),
#  ('Des Moines, IA', 'San Francisco, CA', 2294.87),
#  ('Las Vegas, NV', 'Buffalo, NY', 2923.51),
#  ('Las Vegas, NV', 'Charlotte, NC', 2502.16),
#  ('Las Vegas, NV', 'Columbus, OH', 2559.15),
#  ('Las Vegas, NV', 'Durham, NC', 2739.85),
#  ('Las Vegas, NV', 'Indianapolis, IN', 2381.35),
#  ('Las Vegas, NV', 'Allentown, PA', 2929.61),
#  ('Las Vegas, NV', 'Louisville, KY', 2253.02),
#  ('Las Vegas, NV', 'Norfolk, VA', 2873.26),
#  ('Las Vegas, NV', 'Pawtucket, RI', 3273.58),
#  ('Las Vegas, NV', 'Rochester, NY', 3018.64),
#  ('Las Vegas, NV', 'Scranton, PA', 3128.84),
#  ('Las Vegas, NV', 'Syracuse, NY', 3093.36),
#  ('Las Vegas, NV', 'Toledo, OH', 2602.38),
#  ('Las Vegas, NV', 'Albuquerque, NM', 569.54),
#  ('Las Vegas, NV', 'El Paso, TX', 723.59),
#  ('Las Vegas, NV', 'Fresno, CA', 408.63),
#  ('Las Vegas, NV', 'Des Moines, IA', 1413.38),
#  ('Las Vegas, NV', 'Las Vegas, NV', 0),
#  ('Las Vegas, NV', 'Memphis, TN', 1914.12),
#  ('Las Vegas, NV', 'Nashville, TN', 2129.86),
#  ('Las Vegas, NV', 'Oklahoma City, OK', 1113.69),
#  ('Las Vegas, NV', 'Omaha, NE', 1281.81),
#  ('Las Vegas, NV', 'Reno, NV', 445.29),
#  ('Las Vegas, NV', 'Round Rock, TX', 1341.88),
#  ('Las Vegas, NV', 'West Sacramento, CA', 576.66),
#  ('Las Vegas, NV', 'San Antonio, TX', 1268.15),
#  ('Las Vegas, NV', 'Salt Lake City, UT', 419.97),
#  ('Las Vegas, NV', 'Tacoma, WA', 1119.49),
#  ('Las Vegas, NV', 'Wichita, KS', 1263.86),
#  ('Las Vegas, NV', 'Baltimore, MD', 2837.1),
#  ('Las Vegas, NV', 'Boston, MA', 3314.44),
#  ('Las Vegas, NV', 'New York City, NY', 3028.26),
#  ('Las Vegas, NV', 'St. Petersburg, FL', 2588.92),
#  ('Las Vegas, NV', 'Chicago, IL', 2358.01),
#  ('Las Vegas, NV', 'Cleveland, OH', 2709.75),
#  ('Las Vegas, NV', 'Detroit, MI', 2663.08),
#  ('Las Vegas, NV', 'Kansas City, MO', 1348.62),
#  ('Las Vegas, NV', 'Minneapolis, MN', 1903.86),
#  ('Las Vegas, NV', 'Houston, TX', 1636.56),
#  ('Las Vegas, NV', 'Anaheim, CA', 270.52),
#  ('Las Vegas, NV', 'Oakland, CA', 576.33),
#  ('Las Vegas, NV', 'Seattle, WA', 1106.58),
#  ('Las Vegas, NV', 'Arlington, TX', 1391.31),
#  ('Las Vegas, NV', 'Atlanta, GA', 2261.37),
#  ('Las Vegas, NV', 'Miami, FL', 2772.13),
#  ('Las Vegas, NV', 'Philadelphia, PA', 2938.96),
#  ('Las Vegas, NV', 'Washington, D.C., DC', 2795.47),
#  ('Las Vegas, NV', 'Cincinnati, OH', 2372.84),
#  ...]

# %%
show_map()

# %% [markdown]
# ## Formulation

# %% [markdown]
# ### As a Graph Search Problem
# In its oldest formulation, the TSP is modeled as a search for the shortest **Hamiltionian cycle** in a **labelled, complete graph**. Let's take that one part at a time.
#
# A **graph** has nothing to do with the plots you learned about in science or algebra class. Instead, a graph is a visual representation of data as **vertices** and **edges**.
#
# <p><a href="https://commons.wikimedia.org/wiki/File:6n-graf.svg#/media/File:6n-graf.svg"><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/5/5b/6n-graf.svg/1200px-6n-graf.svg.png" alt="6n-graf.svg" width="200"></a><br>(By <a href="//commons.wikimedia.org/wiki/User:AzaToth" title="User:AzaToth">User:AzaToth</a> - <a href="//commons.wikimedia.org/wiki/File:6n-graf.png" title="File:6n-graf.png">Image:6n-graf.png</a> simlar input data, Public Domain, <a href="https://commons.wikimedia.org/w/index.php?curid=820489">Link</a>)</p>
#
# The vertices (or "nodes") represent locations in space, with the edges ("arcs") connecting them. So, for example, we can treat just about any road map as a graph, with a node for each map coordinate (cities) and arcs representing the roads themselves (highways). If needed **we can label nodes and arcs** with information like road distances or place names. Arcs can also be **directed**, with arrowheads indicating the direction of traversal. This is, in fact, exactly how Geographic Information Systems store data!
#
# Of course, graphs can represent lots of things besides maps. For example, the decision trees used in classification and search are just acyclic (non-looping) directed graphs, with each split represented by a node. Similarly, an airline schedule (with airports, flights, and *times*) is a kind of "time-space network" graph. The planes, crew, passengers, and cargo **flow** through the graph from takeoff to landing to takeoff to ...
#
# A **complete** graph each node is connected to each other node via an arc. In a directed graph with N nodes, that's N(N-1) arcs if they are directional or N(N-1)/2 if not directional.
# <p><a href="https://commons.wikimedia.org/wiki/File:Complete_graph_K7.svg#/media/File:Complete_graph_K7.svg"><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Complete_graph_K7.svg/1200px-Complete_graph_K7.svg.png" alt="Complete graph K7.svg" width="200"></a><br>(By <a href="//commons.wikimedia.org/wiki/User:Dbenbenn" title="User:Dbenbenn">David Benbennick</a> - <span class="int-own-work" lang="en">Own work</span>, Public Domain, <a href="https://commons.wikimedia.org/w/index.php?curid=511711">Link</a>)</p>
#
# A **Hamiltonian** cycle is a closed loop of arcs, connected end-to-end, that pass through every node.
# <p><a href="https://commons.wikimedia.org/wiki/File:GLPK_solution_of_a_travelling_salesman_problem.svg#/media/File:GLPK_solution_of_a_travelling_salesman_problem.svg"><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/11/GLPK_solution_of_a_travelling_salesman_problem.svg/1200px-GLPK_solution_of_a_travelling_salesman_problem.svg.png" alt="GLPK solution of a travelling salesman problem.svg" width="200p"></a><br>(By <a href="//commons.wikimedia.org/wiki/User:Xypron" title="User:Xypron">Xypron</a> - <span class="int-own-work" lang="en">Own work</span>, Public Domain, <a href="https://commons.wikimedia.org/w/index.php?curid=10645665">Link</a>)</p>
#
# **In the TSP,***
# * the nodes are the cities themselves
# * the arcs represent the distance from each city to every other city
# * the objective is to find the shortest distance Hamiltonian cycle through the graph
#
# Note: the graph does not have to cities on a map with a Euclidean distance metric. Any complete graph with distance labels on the arcs will do.
#
# Some of the earliest approaches to the TSP are based on visual inspection of the network graph. These techniques looked for certain properties like **adjacency** or **convex hull shape** or node **degree** to guide the construction of the tour from likely parts and pieces. Christophides's heuristic, for example, used a minimal spanning tree to identify collections of nodes that are "close" to one another and likely to be near-adjacent on the optimal tour. A similar, by simpler approach is taken by the nearest neighbor algorithm covered later in this primer.

# %% [markdown]
# ### As an Integer Program
# We can model the problem as a kind of assignment problem, where each city is assigned a position (1-st, 2-nd, etc.) in the final tour. Each potential solution is then a **permutation** of the nodes, which is explained with a simpler formulation in the enxt section.
#
# If we take a cue from the graph theoretic formulations and focus on the arcs instead of the nodes, we can model the problem as a selection of arcs (in any order) from the complete graph. We can even model it as a Linear Program (LP):
# <p><img src="img/Dantzig-Fulkerson-Johnson_TSP.png" alt="LP formulation" width="800"></a></p>
# The above formulation (from Dantzig, Fulkerson, and Johnson) is trickier than it looks. The number of loop constraints (at the bottom) explodes as we add nodes and arcs. The problem quickly becomes intractible to solve.

# %% [markdown]
# ### As a List Permutation Search Problem
# In computer science the most common formulation is as permutation search: find a list of cities, in the order they are to be visited, with the smallest total path distance.
#
# <p><img src="img/PermutationFormulation.png" alt="Permutation formulation" width="600"></a></p>
#
# This is the most compact definition! All one has to do is shuffle (permute) the cities on the list, looking for the permutation with the shortest loop path length.

# %% [markdown]
# ### A Note About Computational Complexity
# The TSP, while compact, is very difficult. Except for the tiniest toy problems it is impossible to try all N! possible permutations. Further, it is unlikely that anyone will ever find a way to ensure an optimal solution without trying every possible solution.
#
# The TSP is an NP-hard optimization problem. A problem is said to be NP (nondeterministic polynomial) if it is *possible* to reconstruct a known optimal solution in less than exponential time but there is no way to do so for unknown solutions. Confusing, right? Just know that if a problem is NP-complete or NP-hard that it is almost certainly going to take an exponentially increasing amount of time to solve for linearly increasing problem sizes. In the case of the

# %% [markdown]
# ## Operators

# %% [markdown]
# ### Pairwise Swap

# %% [markdown]
# ### 2-Opt Swap

# %% [markdown]
# ## Algorithms

# %% [markdown]
# ### Nearest Neighbor (Greedy Construction)

# %% [markdown]
# Nearest neighbor search is pretty much what it sounds like. Starting with a city (Boston, in our case), construct the tour one city at a time, each time adding the closest unvisited city.
# 1. Make a list of `UNVISITED` cities, initalized with all cities.
# 2. Pick a starting city (in our case, Boston). Add it to the `TOUR` list and remove it from `UNVISITED` list. The city most recently added to the `TOUR` is the  marked as the `HEAD`.
# 3. Find `UNVISITED` city that is closest to the `HEAD`. Remove it from `UNVISITED`, add it to the `TOUR`, and update the `HEAD`.
# 4. Repeat step 3 until the `UNVISITED` list is empty.

# %%
tour = nearest_neighbor(head_idx=30,snapshots=True)
show_map(subtour=tour.city_lst, title="Nearest Neighbor; Distance = "+str(round(tour.miles,2)),closeloop=True)

# %%
# %matplotlib inline
animate_snapshots('nn_snapshots')

# %% [markdown]
# ### A* / Branch & Bound (Constructive Tree Search)

# %% [markdown]
# ### Greedy 2-Opt (Iterative Steepest Descent)

# %% [markdown]
# ### Simulated Annealing (Iterative Pseudo-Random Descent)
